# %%
import pandas as pd
df=pd.read_excel("C:/Users/Admin/Desktop/covid-19/Covid-19.xlsx")
df
# Out:
#          Sno       Date  Year      Time State/UnionTerritory  \
# 0          1 2020-01-30  2020  18:00:00               Kerala
# 1          2 2020-01-31  2020  18:00:00               Kerala
# 2          3 2020-02-01  2020  18:00:00               Kerala
# 3          4 2020-02-02  2020  18:00:00               Kerala
# 4          5 2020-02-03  2020  18:00:00               Kerala
# ...      ...        ...   ...       ...                  ...
# 18105  18106 2021-08-11  2021  08:00:00            Telangana
# 18106  18107 2021-08-11  2021  08:00:00              Tripura
# 18107  18108 2021-08-11  2021  08:00:00          Uttarakhand
# 18108  18109 2021-08-11  2021  08:00:00        Uttar Pradesh
# 18109  18110 2021-08-11  2021  08:00:00          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  datetime64[ns]
#  2   Year                      18110 non-null  int64
#  3   Time                      18110 non-null  object
#  4   State/UnionTerritory      18110 non-null  object
#  5   ConfirmedIndianNational   18110 non-null  object
#  6   ConfirmedForeignNational  18110 non-null  object
#  7   Cured                     18110 non-null  int64
#  8   Deaths                    18110 non-null  int64
#  9   Confirmed                 18110 non-null  int64
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Year                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
df.shape
# Out:
# (18110, 10)

# %%
df.drop(['Sno','Time'],axis=1,inplace=True)

# %%
#df.drop(['Rank'],axis=1,inplace=True)
df
# Out:
#             Date  Year State/UnionTerritory ConfirmedIndianNational  \
# 0     2020-01-30  2020               Kerala                       1
# 1     2020-01-31  2020               Kerala                       1
# 2     2020-02-01  2020               Kerala                       2
# 3     2020-02-02  2020               Kerala                       3
# 4     2020-02-03  2020               Kerala                       3
# ...          ...   ...                  ...                     ...
# 18105 2021-08-11  2021            Telangana                       -
# 18106 2021-08-11  2021              Tripura                       -
# 18107 2021-08-11  2021          Uttarakhand                       -
# 18108 2021-08-11  2021        Uttar Pradesh                       -
# 18109 2021-08-11  2021          West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed
# 0                            0        0       0          1
# ...

# %%
df1=df.iloc[18074:18109,0:8]
df1
# Out:
#             Date  Year                      State/UnionTerritory  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands
# 18075 2021-08-11  2021                            Andhra Pradesh
# 18076 2021-08-11  2021                         Arunachal Pradesh
# 18077 2021-08-11  2021                                     Assam
# 18078 2021-08-11  2021                                     Bihar
# 18079 2021-08-11  2021                                Chandigarh
# 18080 2021-08-11  2021                              Chhattisgarh
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu
# 18082 2021-08-11  2021                                     Delhi
# 18083 2021-08-11  2021                                       Goa
# 18084 2021-08-11  2021                                   Gujarat
# 18085 2021-08-11  2021                                   Haryana
# 18086 2021-08-11  2021                          Himachal Pradesh
# ...

# %%
df1.shape
# Out:
# (35, 8)

# %%
df1.drop(['ConfirmedIndianNational','ConfirmedForeignNational'],axis=1,inplace=True)

# %%
df1
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18075 2021-08-11  2021                            Andhra Pradesh  1952736
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18077 2021-08-11  2021                                     Assam   559684
# 18078 2021-08-11  2021                                     Bihar   715352
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18080 2021-08-11  2021                              Chhattisgarh   988189
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18082 2021-08-11  2021                                     Delhi  1411280
# 18083 2021-08-11  2021                                       Goa   167978
# 18084 2021-08-11  2021                                   Gujarat   814802
# 18085 2021-08-11  2021                                   Haryana   759790
# ...

# %% [markdown]
# # Total Number of death till 11-August-2021

# %%
import numpy as np
s=df1['Deaths']
s1=np.sum(s)
print('Total Number of death till 11-August-2021',s1)
# Out:
# Total Number of death till 11-August-2021 410927

# %% [markdown]
# # Total Number of Cured Pateint till 11-August-2021

# %%
s3=df1['Cured']
s4=np.sum(s3)
print('Total Number of Cured Pateint till 11-August-2021',s4)
# Out:
# Total Number of Cured Pateint till 11-August-2021 29714449

# %%
df2=df1.sort_values(by=['Deaths'])
df2
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18092 2021-08-11  2021                               Lakshadweep    10165
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18097 2021-08-11  2021                                   Mizoram    33722
# 18091 2021-08-11  2021                                    Ladakh    20130
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18103 2021-08-11  2021                                    Sikkim    25095
# 18098 2021-08-11  2021                                  Nagaland    26852
# 18106 2021-08-11  2021                                   Tripura    77811
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18096 2021-08-11  2021                                 Meghalaya    64157
# 18095 2021-08-11  2021                                   Manipur    96776
# ...

# %%
df3=df2.tail(7)
df3
# Out:
#             Date  Year State/UnionTerritory    Cured  Deaths  Confirmed
# 18101 2021-08-11  2021               Punjab   582791   16322     599573
# 18090 2021-08-11  2021               Kerala  3396184   18004    3586693
# 18108 2021-08-11  2021        Uttar Pradesh  1685492   22775    1708812
# 18082 2021-08-11  2021                Delhi  1411280   25068    1436852
# 18104 2021-08-11  2021           Tamil Nadu  2524400   34367    2579130
# 18089 2021-08-11  2021            Karnataka  2861499   36848    2921049
# 18094 2021-08-11  2021          Maharashtra  6159676  134201    6363442

# %% [markdown]
# # States with Highest Death Rates

# %%
s=df3['State/UnionTerritory']
s1=list(s)
j=df3['Deaths']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,5))
plt.bar(s1,j1,color='red')
plt.xlabel('State Name')
plt.ylabel('Frequency')
plt.title('States with highest death rate')
plt.show()

# %%
df1
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18075 2021-08-11  2021                            Andhra Pradesh  1952736
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18077 2021-08-11  2021                                     Assam   559684
# 18078 2021-08-11  2021                                     Bihar   715352
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18080 2021-08-11  2021                              Chhattisgarh   988189
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18082 2021-08-11  2021                                     Delhi  1411280
# 18083 2021-08-11  2021                                       Goa   167978
# 18084 2021-08-11  2021                                   Gujarat   814802
# 18085 2021-08-11  2021                                   Haryana   759790
# ...

# %%
aj=df1.sort_values(by=['Cured'])
aj
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18092 2021-08-11  2021                               Lakshadweep    10165
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18091 2021-08-11  2021                                    Ladakh    20130
# 18103 2021-08-11  2021                                    Sikkim    25095
# 18098 2021-08-11  2021                                  Nagaland    26852
# 18097 2021-08-11  2021                                   Mizoram    33722
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18096 2021-08-11  2021                                 Meghalaya    64157
# 18106 2021-08-11  2021                                   Tripura    77811
# 18095 2021-08-11  2021                                   Manipur    96776
# ...

# %%
aj1=aj.tail(7)
aj1
# Out:
#             Date  Year State/UnionTerritory    Cured  Deaths  Confirmed
# 18082 2021-08-11  2021                Delhi  1411280   25068    1436852
# 18108 2021-08-11  2021        Uttar Pradesh  1685492   22775    1708812
# 18075 2021-08-11  2021       Andhra Pradesh  1952736   13564    1985182
# 18104 2021-08-11  2021           Tamil Nadu  2524400   34367    2579130
# 18089 2021-08-11  2021            Karnataka  2861499   36848    2921049
# 18090 2021-08-11  2021               Kerala  3396184   18004    3586693
# 18094 2021-08-11  2021          Maharashtra  6159676  134201    6363442

# %% [markdown]
# # States with Highest Recovery Rates

# %%
s=aj1['State/UnionTerritory']
s1=list(s)
j=aj1['Cured']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,10))
plt.pie(j1,labels=s1,autopct='%1.2f%%')
plt.title('States with Highest Recovery Rates')
plt.show()

# %%
df1
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18075 2021-08-11  2021                            Andhra Pradesh  1952736
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18077 2021-08-11  2021                                     Assam   559684
# 18078 2021-08-11  2021                                     Bihar   715352
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18080 2021-08-11  2021                              Chhattisgarh   988189
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18082 2021-08-11  2021                                     Delhi  1411280
# 18083 2021-08-11  2021                                       Goa   167978
# 18084 2021-08-11  2021                                   Gujarat   814802
# 18085 2021-08-11  2021                                   Haryana   759790
# ...

# %%
ig=df1.sort_values(by=['Confirmed'])
ig
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18092 2021-08-11  2021                               Lakshadweep    10165
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18091 2021-08-11  2021                                    Ladakh    20130
# 18103 2021-08-11  2021                                    Sikkim    25095
# 18098 2021-08-11  2021                                  Nagaland    26852
# 18097 2021-08-11  2021                                   Mizoram    33722
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18096 2021-08-11  2021                                 Meghalaya    64157
# 18106 2021-08-11  2021                                   Tripura    77811
# 18095 2021-08-11  2021                                   Manipur    96776
# ...

# %%
ig1=ig.tail(7)
ig1
# Out:
#             Date  Year State/UnionTerritory    Cured  Deaths  Confirmed
# 18082 2021-08-11  2021                Delhi  1411280   25068    1436852
# 18108 2021-08-11  2021        Uttar Pradesh  1685492   22775    1708812
# 18075 2021-08-11  2021       Andhra Pradesh  1952736   13564    1985182
# 18104 2021-08-11  2021           Tamil Nadu  2524400   34367    2579130
# 18089 2021-08-11  2021            Karnataka  2861499   36848    2921049
# 18090 2021-08-11  2021               Kerala  3396184   18004    3586693
# 18094 2021-08-11  2021          Maharashtra  6159676  134201    6363442

# %% [markdown]
# # States that are worstly affected with covid

# %%
s=ig1['State/UnionTerritory']
s1=list(s)
j=ig1['Confirmed']
j1=list(j)
import matplotlib.pyplot as plt
plt.scatter(j1,s1,color='red',marker='v')
plt.show()

# %%
df1
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18075 2021-08-11  2021                            Andhra Pradesh  1952736
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18077 2021-08-11  2021                                     Assam   559684
# 18078 2021-08-11  2021                                     Bihar   715352
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18080 2021-08-11  2021                              Chhattisgarh   988189
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18082 2021-08-11  2021                                     Delhi  1411280
# 18083 2021-08-11  2021                                       Goa   167978
# 18084 2021-08-11  2021                                   Gujarat   814802
# 18085 2021-08-11  2021                                   Haryana   759790
# ...

# %%
sg=df1.sort_values(by=['Deaths'])
sg
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18092 2021-08-11  2021                               Lakshadweep    10165
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18097 2021-08-11  2021                                   Mizoram    33722
# 18091 2021-08-11  2021                                    Ladakh    20130
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18103 2021-08-11  2021                                    Sikkim    25095
# 18098 2021-08-11  2021                                  Nagaland    26852
# 18106 2021-08-11  2021                                   Tripura    77811
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18096 2021-08-11  2021                                 Meghalaya    64157
# 18095 2021-08-11  2021                                   Manipur    96776
# ...

# %%
sg1=sg.head(7)
sg1
# Out:
#             Date  Year                      State/UnionTerritory  Cured  \
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu  10646
# 18092 2021-08-11  2021                               Lakshadweep  10165
# 18074 2021-08-11  2021               Andaman and Nicobar Islands   7412
# 18097 2021-08-11  2021                                   Mizoram  33722
# 18091 2021-08-11  2021                                    Ladakh  20130
# 18076 2021-08-11  2021                         Arunachal Pradesh  47821
# 18103 2021-08-11  2021                                    Sikkim  25095
#
#        Deaths  Confirmed
# 18081       4      10654
# 18092      51      10263
# 18074     129       7548
# 18097     171      46320
# 18091     207      20411
# 18076     248      50605
# 18103     356      28018

# %% [markdown]
# # States with lowest death rates

# %%
s=sg1['State/UnionTerritory']
s1=list(s)
j=sg1['Deaths']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,5))
plt.bar(s1,j1,color='green')
plt.xlabel('State Name')
plt.ylabel('Frequency')
plt.title('States with Lowest Death rate')
plt.show()

# %%
rg=df1.sort_values(by=['Confirmed'])
rg
# Out:
#             Date  Year                      State/UnionTerritory    Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands     7412
# 18092 2021-08-11  2021                               Lakshadweep    10165
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu    10646
# 18091 2021-08-11  2021                                    Ladakh    20130
# 18103 2021-08-11  2021                                    Sikkim    25095
# 18098 2021-08-11  2021                                  Nagaland    26852
# 18097 2021-08-11  2021                                   Mizoram    33722
# 18076 2021-08-11  2021                         Arunachal Pradesh    47821
# 18079 2021-08-11  2021                                Chandigarh    61150
# 18096 2021-08-11  2021                                 Meghalaya    64157
# 18106 2021-08-11  2021                                   Tripura    77811
# 18095 2021-08-11  2021                                   Manipur    96776
# ...

# %%
rg1=rg.head(7)
rg1
# Out:
#             Date  Year                      State/UnionTerritory  Cured  \
# 18074 2021-08-11  2021               Andaman and Nicobar Islands   7412
# 18092 2021-08-11  2021                               Lakshadweep  10165
# 18081 2021-08-11  2021  Dadra and Nagar Haveli and Daman and Diu  10646
# 18091 2021-08-11  2021                                    Ladakh  20130
# 18103 2021-08-11  2021                                    Sikkim  25095
# 18098 2021-08-11  2021                                  Nagaland  26852
# 18097 2021-08-11  2021                                   Mizoram  33722
#
#        Deaths  Confirmed
# 18074     129       7548
# 18092      51      10263
# 18081       4      10654
# 18091     207      20411
# 18103     356      28018
# 18098     585      28811
# 18097     171      46320

# %% [markdown]
# # States that are least affected with Covid

# %%
s=rg1['State/UnionTerritory']
s1=list(s)
j=rg1['Confirmed']
j1=list(j)

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,10))
plt.pie(j1,labels=s1,autopct='%1.2f%%')
plt.title('States that are least affected with Covid')
plt.show()

# %% [markdown]
# # Month wise corona case prediction in year 2021

# %%
import numpy as np

x=np.array([[1],[2],[3],[4]])

y=np.array([[5157],[11007],[225022],[555285]])

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
coef=lr.coef_[0]
coef
# Out:
# array([186439.9])

# %%
intercept=lr.intercept_
intercept
# Out:
# array([-266982.])

# %%
exp=int(input('Type month number to know confirmed cases'))
pred_sal=coef*exp+intercept
pred_sal
# Out:
# Type month number to know confirmed cases10
# array([1597417.])

# %%
pred=lr.predict(x)
pred
# Out:
# array([[-80542.1],
#        [105897.8],
#        [292337.7],
#        [478777.6]])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,pred)
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y,pred))
# Out:
# 0.8666880607288149

# %%
import numpy
x=np.array([1,2,3,4])
y=np.array([5157,11007,225022,555285])

mymodel=numpy.poly1d(numpy.polyfit(x,y,5))

pred=mymodel(x)
pred

import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,pred)
plt.show()

from sklearn.metrics import r2_score
print(r2_score(y,pred))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 1.0
