# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C:/Users/Admin/Desktop/heat attack/heart_attack.xlsx")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.shape
# Out:
# (918, 12)

# %% [markdown]
# # TYPE OF CHEST PAIN

# %%
s=df['ChestPainType']
s1=list(s)
s2=pd.Series(s1,dtype="category")
s2
# Out:
# 0      ATA
# 1      NAP
# 2      ATA
# 3      ASY
# 4      NAP
#       ...
# 913     TA
# 914    ASY
# 915    ASY
# 916    ATA
# 917    NAP
# Length: 918, dtype: category
# Categories (4, object): ['ASY', 'ATA', 'NAP', 'TA']

# %% [markdown]
# # TYPE OF ECG

# %%
s=df['RestingECG']
s1=list(s)
s2=pd.Series(s1,dtype="category")
s2
# Out:
# 0      Normal
# 1      Normal
# 2          ST
# 3      Normal
# 4      Normal
#         ...
# 913    Normal
# 914    Normal
# 915    Normal
# 916       LVH
# 917    Normal
# Length: 918, dtype: category
# Categories (3, object): ['LVH', 'Normal', 'ST']

# %% [markdown]
# # TYPE OF ST SLOPE

# %%
s=df['ST_Slope']
s1=list(s)
s2=pd.Series(s1,dtype="category")
s2
# Out:
# 0        Up
# 1      Flat
# 2        Up
# 3      Flat
# 4        Up
#        ...
# 913    Flat
# 914    Flat
# 915    Flat
# 916    Flat
# 917      Up
# Length: 918, dtype: category
# Categories (3, object): ['Down', 'Flat', 'Up']

# %%
df.sort_values(by=['Age'],inplace=True)
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
# 219   29   M           ATA        140          263          0     Normal
# 170   29   M           ATA        120          243          0     Normal
# 829   29   M           ATA        130          204          0        LVH
# 215   30   F            TA        170          237          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 491   75   M           ASY        170          203          1         ST
# 541   76   M           NAP        104          113          0        LVH
# 688   76   F           NAP        140          197          0         ST
# 814   77   M           ASY        125          304          0        LVH
# 447   77   M           ASY        124          171          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # AVERAGE AGE OF HEART ATTACK

# %%
s=df['Age']
z=np.mean(s)
z
# Out:
# 53.510893246187365

# %% [markdown]
# # MINIMUM AGE OF PATIENT GOT HEART ATTACK

# %%
df.head(1)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 208    185              N      0.0       Up             0

# %% [markdown]
# # MAXIMUM AGE OF PATIENT GOT HEART ATTACK

# %%
df.tail(1)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 447   77   M           ASY        124          171          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 447    110              Y      2.0       Up             1

# %% [markdown]
# # SEX RATIO ACCORDING TO CHEST PAIN TYPE

# %%
x=df.groupby(['ChestPainType','Sex'])['Sex'].count()
y=df.groupby(['ChestPainType'])['Sex'].count()
r=((x/y)*100).round(2)
r
# Out:
# ChestPainType  Sex
# ASY            F      14.11
#                M      85.89
# ATA            F      34.68
#                M      65.32
# NAP            F      26.11
#                M      73.89
# TA             F      21.74
#                M      78.26
# Name: Sex, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
w=0.4
x=['ASY','ATA','NAP','TA']
FEMALE=[14.11,34.68,26.11,21.74]
MALE=[85.89,65.32,73.89,78.26]

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]

plt.bar(bar1,FEMALE,w,label="FEMALE")
plt.bar(bar2,MALE,w,label="MALE")
plt.xlabel("Chest Pain")
plt.xlabel("Sex")
plt.title("Chest Pain in Male & Female")
plt.xticks(bar1,x)
plt.legend()
plt.show()

# %% [markdown]
# # Maximum RestingBP,Cholesterol & MaxHR in ATA

# %%
df1=df[df['ChestPainType']=='ATA']
df1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
# 219   29   M           ATA        140          263          0     Normal
# 170   29   M           ATA        120          243          0     Normal
# 829   29   M           ATA        130          204          0        LVH
# 203   31   F           ATA        100          219          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 663   66   M           ATA        160          246          0     Normal
# 687   70   M           ATA        156          245          0        LVH
# 870   71   F           ATA        160          302          0     Normal
# 315   74   M           ATA        145            0          1         ST
# 619   74   F           ATA        120          269          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df11=df1.sort_values(by=['RestingBP','Cholesterol','MaxHR'])
df111=df11.tail(1)
df111
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 759    195              N      0.0       Up             1

# %% [markdown]
# # Maximum RestingBP,Cholesterol & MaxHR in ASY

# %%
df2=df[df['ChestPainType']=='ASY']
df22=df2.sort_values(by=['RestingBP','Cholesterol','MaxHR'])
df222=df22.tail(1)
df222
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 732   56   F           ASY        200          288          1        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 732    133              Y      4.0     Down             1

# %% [markdown]
# # Maximum RestingBP,Cholesterol & MaxHR in NAP

# %%
df3=df[df['ChestPainType']=='NAP']
df33=df3.sort_values(by=['RestingBP','Cholesterol','MaxHR'])
df333=df33.tail(1)
df333
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 399   61   M           NAP        200            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 399     70              N      0.0     Flat             1

# %% [markdown]
# # Maximum RestingBP,Cholesterol & MaxHR in TA

# %%
df4=df[df['ChestPainType']=='TA']
df44=df4.sort_values(by=['RestingBP','Cholesterol','MaxHR'])
df444=df44.tail(1)
df444
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 702   59   M            TA        178          270          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 702    145              N      4.2     Down             0

# %%
is1=pd.concat([df111,df222],axis=0)
is1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 759   54   M           ATA        192          283          0        LVH
# 732   56   F           ASY        200          288          1        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 759    195              N      0.0       Up             1
# 732    133              Y      4.0     Down             1

# %%
is2=pd.concat([is1,df333],axis=0)
is2
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 759   54   M           ATA        192          283          0        LVH
# 732   56   F           ASY        200          288          1        LVH
# 399   61   M           NAP        200            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 759    195              N      0.0       Up             1
# 732    133              Y      4.0     Down             1
# 399     70              N      0.0     Flat             1

# %%
is3=pd.concat([is2,df444],axis=0)
is3
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 759   54   M           ATA        192          283          0        LVH
# 732   56   F           ASY        200          288          1        LVH
# 399   61   M           NAP        200            0          1         ST
# 702   59   M            TA        178          270          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 759    195              N      0.0       Up             1
# 732    133              Y      4.0     Down             1
# 399     70              N      0.0     Flat             1
# 702    145              N      4.2     Down             0

# %% [markdown]
# # HIGHEST RESTING BP IN ALL CHEST PAIN TYPE

# %%
s=is3['ChestPainType']
s1=list(s)
j=is3['RestingBP']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,5))
plt.bar(s1,j1,color='red')
plt.xlabel('Chest Pain')
plt.ylabel('Resting BP')
plt.title('Highest Resting BP in all Chest pain type')
plt.show()

# %% [markdown]
# # HIGHEST CHOLESTEROL IN ALL CHEST PAIN TYPE

# %%
s=is3['ChestPainType']
s1=list(s)
j=is3['Cholesterol']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,5))
plt.bar(s1,j1,color='BLUE')
plt.xlabel('Chest Pain')
plt.ylabel('Cholesterol')
plt.title('Highest Cholesterol in all Chest pain type')
plt.show()

# %% [markdown]
# # MAX HR IN ALL CHEST PAIN TYPE

# %%
s=is3['ChestPainType']
s1=list(s)
j=is3['MaxHR']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,5))
plt.bar(s1,j1,color='YELLOW')
plt.xlabel('Chest Pain')
plt.ylabel('MaxHR')
plt.title('Highest MaxHR in all Chest pain type')
plt.show()
