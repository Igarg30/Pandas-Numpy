# %%
import pandas as pd
df=pd.read_excel("C:/Users/Admin/Desktop/ipl data/average strike - Copy.xlsx")
df
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        516 non-null    object
#  1   total_runs     516 non-null    int64
#  2   out            516 non-null    int64
#  3   numberofballs  516 non-null    int64
#  4   average        482 non-null    float64
#  5   strikerate     516 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 24.3+ KB

# %%
df.isnull().sum()
# Out:
# batsman           0
# total_runs        0
# out               0
# numberofballs     0
# average          34
# strikerate        0
# dtype: int64

# %%
df.fillna({'average':0},inplace=True)

# %%
df.isnull().sum()
# Out:
# batsman          0
# total_runs       0
# out              0
# numberofballs    0
# average          0
# strikerate       0
# dtype: int64

# %%
df1=df[df['strikerate']>170]

# %%
#Batsman whose strike rate are above 170
s=df1['batsman']
s1=list(s)
j=df1['strikerate']
j1=list(j)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,10))
plt.pie(j1,labels=s1,autopct='%1.2f%%')
plt.title('Batsman whose strike rate are above 170')
plt.show()

# %%
df2=df[df['average']>30]
df3=df2[df['out']>100]
df3
# Out:
# <ipython-input-8-32fcd128f8f8>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3=df2[df['out']>100]
#            batsman  total_runs  out  numberofballs    average  strikerate
# 0          V Kohli        5426  152           4111  35.697368  131.987351
# 1         SK Raina        5386  160           3916  33.662500  137.538304
# 2        RG Sharma        4902  161           3742  30.447205  130.999466
# 3        DA Warner        4717  114           3292  41.377193  143.286756
# 4         S Dhawan        4601  137           3665  33.583942  125.538881
# 5         CH Gayle        4525  110           2972  41.136364  152.254374
# 6         MS Dhoni        4450  118           3206  37.711864  138.802246
# 8   AB de Villiers        4414  104           2902  42.442308  152.101999
# 9        G Gambhir        4219  134           3400  31.485075  124.088235
# 10       AM Rahane        3834  117           3133  32.769231  122.374721
# ...

# %%
#batsman whose average is more than 30 and out is more than 100
s=df3['average']
s1=list(s)
j=df3['batsman']
j1=list(j)
fig=plt.figure(figsize=(12,5))
plt.bar(j1,s1,color='red')
plt.xlabel('PLAYER NAME')
plt.ylabel('FREQUENCY')
plt.title('Player whose average is more than 30 and out is more than 100')

plt.show()

# %%
df4=df[df['total_runs']>4300]
df5=df4[df['out']>100]
df5
# Out:
# <ipython-input-10-5ec9c3d8e2c1>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df5=df4[df['out']>100]
#           batsman  total_runs  out  numberofballs    average  strikerate
# 0         V Kohli        5426  152           4111  35.697368  131.987351
# 1        SK Raina        5386  160           3916  33.662500  137.538304
# 2       RG Sharma        4902  161           3742  30.447205  130.999466
# 3       DA Warner        4717  114           3292  41.377193  143.286756
# 4        S Dhawan        4601  137           3665  33.583942  125.538881
# 5        CH Gayle        4525  110           2972  41.136364  152.254374
# 6        MS Dhoni        4450  118           3206  37.711864  138.802246
# 7      RV Uthappa        4420  156           3381  28.333333  130.730553
# 8  AB de Villiers        4414  104           2902  42.442308  152.101999

# %%
# scatter graph for players who score more than 4300 and out is more than 100
s=df5['total_runs']
s1=list(s)
j=df5['out']
j1=list(j)
plt.scatter(j1,s1,color='red',marker='v')
plt.xlabel('No.of out')
plt.ylabel('Total Run')
plt.title('players who score more than 4300 and out is more than 100')
plt.show()

# %%
df
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
#sorting data on bases of highest average
df.sort_values(by=['average'],ascending=False,inplace=True)

# %%
#rank player on basis of average
df['Rank']=df['average'].rank(ascending=False).astype('int32')
df
# Out:
#               batsman  total_runs  out  numberofballs    average  strikerate  \
# 243     Iqbal Abdulla          88    1             83  88.000000  106.024096
# 109        J Bairstow         459    8            284  57.375000  161.619718
# 180        MN van Wyk         167    3            132  55.666667  126.515152
# 159    PD Collingwood         203    4            156  50.750000  130.128205
# 97            HM Amla         577   13            407  44.384615  141.769042
# ..                ...         ...  ...            ...        ...         ...
# 418        SM Harwood           9    0             13   0.000000   69.230769
# 478  Mashrafe Mortaza           2    0              2   0.000000  100.000000
# 445           R Salam           5    0              4   0.000000  125.000000
# 481           RG More           2    0              2   0.000000  100.000000
# 515         S Kaushik           0    1              1   0.000000    0.000000
#
#      Rank
# 243     1
# 109     2
# ...

# %%
#median of total run
import numpy as np
s=df['total_runs']
z=np.median(s)
z
# Out:
# 74.0

# %%
#players whose total run are more than median value
df1=df[df['total_runs']>74]

# %%
# finding mean of number of ball
s=df1['numberofballs']
z=np.mean(s)
z
# Out:
# 648.4728682170543

# %%
#playes whose runs are more than median value of total run and mean value of number of balls
df2=df[df['numberofballs']>104]
df2
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate  \
# 109      J Bairstow         459    8            284  57.375000  161.619718
# 180      MN van Wyk         167    3            132  55.666667  126.515152
# 159  PD Collingwood         203    4            156  50.750000  130.128205
# 97          HM Amla         577   13            407  44.384615  141.769042
# 8    AB de Villiers        4414  104           2902  42.442308  152.101999
# ..              ...         ...  ...            ...        ...         ...
# 214       RJ Harris         117   12            111   9.750000  105.405405
# 208       MM Sharma         123   14            117   8.785714  105.128205
# 168         B Kumar         184   23            189   8.000000   97.354497
# 216          Z Khan         117   15            138   7.800000   84.782609
# 181        DW Steyn         166   22            157   7.545455  105.732484
#
#      Rank
# 109     2
# 180     3
# 159     4
# 97      5
# ...

# %%
# select top 5 from above data
df3=df2.head()
df3
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate  \
# 109      J Bairstow         459    8            284  57.375000  161.619718
# 180      MN van Wyk         167    3            132  55.666667  126.515152
# 159  PD Collingwood         203    4            156  50.750000  130.128205
# 97          HM Amla         577   13            407  44.384615  141.769042
# 8    AB de Villiers        4414  104           2902  42.442308  152.101999
#
#      Rank
# 109     2
# 180     3
# 159     4
# 97      5
# 8       6

# %%
# his graphical representation
s=df3['total_runs']
s1=list(s)
s1
j=df3['batsman']
j1=list(j)
j1
# Out:
# ['J Bairstow', 'MN van Wyk', 'PD Collingwood', 'HM Amla', 'AB de Villiers']

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,5))
plt.bar(j1,s1,color='red')
plt.xlabel('Player Name')
plt.ylabel('Total Run')
plt.title('TOP 5 player with more whose score more than median value and number of ball is more than mean value')
plt.show()
